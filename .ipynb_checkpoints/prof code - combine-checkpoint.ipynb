# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import imageio
import os
from PIL import Image


import sys
sys.path 
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -q -U keras-tuner
import keras_tuner as kt



tr = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr.csv')
tr1 =tr.copy() 
tr1['cdate'] = pd.to_datetime(tr1['cdate']).values.astype(np.float64)/8.64e+13
tr1 = tr1.fillna(0)


pred = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred.csv')

te = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte.csv')
te1 = te.copy()
te1['cdate'] = pd.to_datetime(te1['cdate']).values.astype(np.float64)/8.64e+13
te1 = te1.fillna(0)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/tanlu/Library/Python/3.9/lib/python/site-packages (21.3.1)

# %%
zz = np.zeros([tr1.shape[0],28,28])
yy = pd.qcut(tr1['total'], 10, labels = range(10))

# %%
found = list()
for ii in range(tr1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, tr1.shape[0]))
    if tr1['ext'][ii] == '.png':
        id = tr1.loc[ii,'id']
        ff = tr1.loc[ii, 'id'] + tr1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue
        
        pic = imageio.imread(path)
        pic = Image.fromarray(pic).resize((28,28))
        
        try:
            pic = np.mean(pic,axis = 2)
        except:
            pic = np.array(pic)
        
        found.append(ii)
        # print(pic.shape)
        zz[ii,:,:] = pic
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
zz = zz/255

# %%
zzte = np.zeros([tr1.shape[0],28,28])
found = list()
for ii in range(te1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, te1.shape[0]))
    if te1['ext'][ii] == '.png':
        id = te1.loc[ii,'id']
        ff = te1.loc[ii, 'id'] + te1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue
        
        pic = imageio.imread(path)
        pic = Image.fromarray(pic).resize((28,28))
        
        try:
            pic = np.mean(pic,axis = 2)
        except:
            pic = np.array(pic)
        
        found.append(ii)
        # print(pic.shape)
        zzte[ii,:,:] = pic
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
zzte = zzte/255

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (28,28)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])
model.compile(optimizer = 'adam', loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])
model.fit(zz, yy, epochs = 50)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 0s 689us/step - loss: 2.3020 - accuracy: 0.1174
# Epoch 2/50
# 217/217 [==============================] - 0s 670us/step - loss: 2.2751 - accuracy: 0.1364
# Epoch 3/50
# 217/217 [==============================] - 0s 666us/step - loss: 2.2643 - accuracy: 0.1331
# Epoch 4/50
# 217/217 [==============================] - 0s 666us/step - loss: 2.2580 - accuracy: 0.1442
# Epoch 5/50
# 217/217 [==============================] - 0s 701us/step - loss: 2.2479 - accuracy: 0.1436
# Epoch 6/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.2383 - accuracy: 0.1469
# Epoch 7/50
# 217/217 [==============================] - 0s 665us/step - loss: 2.2296 - accuracy: 0.1501
# Epoch 8/50
# 217/217 [==============================] - 0s 670us/step - loss: 2.2236 - accuracy: 0.1530
# Epoch 9/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.2170 - accuracy: 0.1566
# Epoch 10/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.2087 - accuracy: 0.1575
# Epoch 11/50
# 217/217 [==============================] - 0s 671us/step - loss: 2.2029 - accuracy: 0.1604
# Epoch 12/50
# 217/217 [==============================] - 0s 665us/step - loss: 2.1939 - accuracy: 0.1684
# Epoch 13/50
# 217/217 [==============================] - 0s 670us/step - loss: 2.1908 - accuracy: 0.1699
# Epoch 14/50
# 217/217 [==============================] - 0s 674us/step - loss: 2.1829 - accuracy: 0.1692
# Epoch 15/50
# 217/217 [==============================] - 0s 664us/step - loss: 2.1770 - accuracy: 0.1689
# Epoch 16/50
# 217/217 [==============================] - 0s 673us/step - loss: 2.1728 - accuracy: 0.1730
# Epoch 17/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.1654 - accuracy: 0.1792
# Epoch 18/50
# 217/217 [==============================] - 0s 665us/step - loss: 2.1598 - accuracy: 0.1808
# Epoch 19/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.1540 - accuracy: 0.1880
# Epoch 20/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1497 - accuracy: 0.1863
# Epoch 21/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1492 - accuracy: 0.1899
# Epoch 22/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1452 - accuracy: 0.1903
# Epoch 23/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1396 - accuracy: 0.1927
# Epoch 24/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.1326 - accuracy: 0.1971
# Epoch 25/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1313 - accuracy: 0.1944
# Epoch 26/50
# 217/217 [==============================] - 0s 666us/step - loss: 2.1230 - accuracy: 0.2009
# Epoch 27/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.1207 - accuracy: 0.1973
# Epoch 28/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1111 - accuracy: 0.2051
# Epoch 29/50
# 217/217 [==============================] - 0s 670us/step - loss: 2.1079 - accuracy: 0.2015
# Epoch 30/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.1076 - accuracy: 0.2034
# Epoch 31/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.1073 - accuracy: 0.2041
# Epoch 32/50
# 217/217 [==============================] - 0s 663us/step - loss: 2.1003 - accuracy: 0.2097
# Epoch 33/50
# 217/217 [==============================] - 0s 671us/step - loss: 2.0964 - accuracy: 0.2047
# Epoch 34/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.0921 - accuracy: 0.2087
# Epoch 35/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.0880 - accuracy: 0.2142
# Epoch 36/50
# 217/217 [==============================] - 0s 673us/step - loss: 2.0838 - accuracy: 0.2129
# Epoch 37/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.0841 - accuracy: 0.2136
# Epoch 38/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.0824 - accuracy: 0.2139
# Epoch 39/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.0792 - accuracy: 0.2155
# Epoch 40/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.0774 - accuracy: 0.2135
# Epoch 41/50
# 217/217 [==============================] - 0s 671us/step - loss: 2.0718 - accuracy: 0.2222
# Epoch 42/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.0658 - accuracy: 0.2243
# Epoch 43/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.0634 - accuracy: 0.2214
# Epoch 44/50
# 217/217 [==============================] - 0s 668us/step - loss: 2.0643 - accuracy: 0.2207
# Epoch 45/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.0616 - accuracy: 0.2190
# Epoch 46/50
# 217/217 [==============================] - 0s 665us/step - loss: 2.0546 - accuracy: 0.2240
# Epoch 47/50
# 217/217 [==============================] - 0s 667us/step - loss: 2.0511 - accuracy: 0.2253
# Epoch 48/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.0550 - accuracy: 0.2249
# Epoch 49/50
# 217/217 [==============================] - 0s 669us/step - loss: 2.0485 - accuracy: 0.2214
# Epoch 50/50
# 217/217 [==============================] - 0s 677us/step - loss: 2.0509 - accuracy: 0.2223

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
pred_i = pred.copy()
pred_i['total'] = probability_model.predict(zzte)
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_image.csv', index = False)

# %%
#prof code
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(zzte)
result = np.argmax(predictions,axis = 1)
qq = np.quantile(tr['total'],q = np.array(range(1,11))/11)
result2 = qq[result]
result3 = result2
result3[~np.array(found)] = np.median(tr1['total'])
pred_i = pred.copy()
pred_i['total'] = result3
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_i.csv', index = False)

# %%
#X1te = pred_i
predictions = probability_model.predict(zz)
result = np.argmax(predictions,axis=1)
qq = np.quantile(tr1['total'],q = np.array(range(1,11))/11)
result2= qq[result]
result3 = result2
result.shape
# Out:
# (6914,)

# %%
found = list()
for ii in range(tr1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, tr1.shape[0]))
    if te1['ext'][ii] == '.png':
        id = tr1.loc[ii,'id']
        ff = tr1.loc[ii, 'id'] + tr1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue       
        found.append(ii)
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
result3[~np.array(found)] = np.median(tr1['total'])
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/result3.csv', index = False)
# result3 = predictions of the dnn on the training set
# save this to result3.csv
# prid_i = predictions of dnn on the testing set
# save this to pred_i.csv

# %%
# cnn

def create_cnn(width = 28, height = 28, regress = False):
    inputShape = (height,width)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters = 32,kernel_size = 3 ,activation = 'relu',input_shape = (28,28,1),padding = "same"))
    model.add(tf.keras.layers.MaxPooling2D(pool_size = 2))
    model.add(tf.keras.layers.Conv2D(filters = 64,kernel_size = 3 ,activation = 'relu',padding = "same"))
    model.add(tf.keras.layers.MaxPooling2D(pool_size = 2))
    model.add(tf.keras.layers.Conv2D(filters = 128,kernel_size = 3 ,activation = 'relu',padding = "same"))

    model.add(tf.keras.layers.Flatten())
    #model.add(tf.keras.layers.Dense(128, activation = 'relu'))
    #model.add(tf.keras.layers.Dropout(0.5))
    #model.add(tf.keras.layers.Dense(64, activation = 'relu'))
    #model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation = 'softmax'))
    #if regress:
    #    model.add(tf.keras.layers.Dense(1, activation="linear"))
    return model

# %%
cnn = create_cnn(28,28,regress = False)
# opt = tf.keras.optimizers.Adam(learning_rate=1e-1, decay=1e-1 / 100)
# model.compile(loss="mean_absolute_error", optimizer=opt)
cnn.compile(loss='sparse_categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
cnn.fit(x= zz, y=yy,epochs= 50)
probability_model = tf.keras.Sequential([cnn, tf.keras.layers.Softmax()])
pred_i = pred.copy()
pred_i['total'] = probability_model.predict(zzte)
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_i.csv', index = False)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.2927 - accuracy: 0.1203
# Epoch 2/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.2638 - accuracy: 0.1357
# Epoch 3/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.2313 - accuracy: 0.1605
# Epoch 4/50
# 217/217 [==============================] - 3s 13ms/step - loss: 2.1922 - accuracy: 0.1756
# Epoch 5/50
# 217/217 [==============================] - 3s 13ms/step - loss: 2.1516 - accuracy: 0.1873
# Epoch 6/50
# 217/217 [==============================] - 3s 13ms/step - loss: 2.1067 - accuracy: 0.2013
# Epoch 7/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.0563 - accuracy: 0.2227
# Epoch 8/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.0144 - accuracy: 0.2384
# Epoch 9/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.9708 - accuracy: 0.2560
# Epoch 10/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.9320 - accuracy: 0.2729
# Epoch 11/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.8908 - accuracy: 0.2874
# Epoch 12/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.8520 - accuracy: 0.3062
# Epoch 13/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.8166 - accuracy: 0.3150
# Epoch 14/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.7897 - accuracy: 0.3288
# Epoch 15/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.7499 - accuracy: 0.3421
# Epoch 16/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.7132 - accuracy: 0.3565
# Epoch 17/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6821 - accuracy: 0.3652
# Epoch 18/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6607 - accuracy: 0.3697
# Epoch 19/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.6564 - accuracy: 0.3807
# Epoch 20/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6256 - accuracy: 0.3872
# Epoch 21/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6069 - accuracy: 0.3937
# Epoch 22/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5933 - accuracy: 0.3933
# Epoch 23/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5744 - accuracy: 0.4015
# Epoch 24/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5701 - accuracy: 0.4037
# Epoch 25/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5549 - accuracy: 0.4093
# Epoch 26/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5492 - accuracy: 0.4080
# Epoch 27/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5313 - accuracy: 0.4118
# Epoch 28/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5412 - accuracy: 0.4131
# Epoch 29/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5220 - accuracy: 0.4155
# Epoch 30/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5221 - accuracy: 0.4155
# Epoch 31/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5152 - accuracy: 0.4178
# Epoch 32/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.5131 - accuracy: 0.4249
# Epoch 33/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5102 - accuracy: 0.4216
# Epoch 34/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4967 - accuracy: 0.4228
# Epoch 35/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4920 - accuracy: 0.4270
# Epoch 36/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4917 - accuracy: 0.4281
# Epoch 37/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4834 - accuracy: 0.4268
# Epoch 38/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4841 - accuracy: 0.4303
# Epoch 39/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4781 - accuracy: 0.4316
# Epoch 40/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4753 - accuracy: 0.4310
# Epoch 41/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4679 - accuracy: 0.4320
# Epoch 42/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4691 - accuracy: 0.4358
# Epoch 43/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4686 - accuracy: 0.4314
# Epoch 44/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4745 - accuracy: 0.4327
# Epoch 45/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4756 - accuracy: 0.4342
# Epoch 46/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4571 - accuracy: 0.4362
# Epoch 47/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4560 - accuracy: 0.4343
# Epoch 48/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4586 - accuracy: 0.4416
# Epoch 49/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4464 - accuracy: 0.4404
# Epoch 50/50
# 217/217 [==============================] - 3s 12ms/step - loss: 1.4430 - accuracy: 0.4453

# %%
predictions = probability_model.predict(zz)
result = np.argmax(predictions,axis=1)
qq = np.quantile(tr1['total'],q = np.array(range(1,11))/11)
result2= qq[result]
result3 = result2
result.shape
# Out:
# (6914,)

# %%
found = list()
for ii in range(tr1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, tr1.shape[0]))
    if te1['ext'][ii] == '.png':
        id = tr1.loc[ii,'id']
        ff = tr1.loc[ii, 'id'] + tr1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue       
        found.append(ii)
result3[~np.array(found)] = np.median(tr1['total'])
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/result3.csv', index = False)
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
import pandas as pd
import numpy as np

# Read data

XYtr = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr.csv')
tr_result3 = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/result3.csv')

XYtr1 = XYtr.copy() # from stackoverflow
XYtr1['cdate'] = pd.to_datetime(XYtr1['cdate']).values.astype(np.float64)/8.64e+13

Ytr1 = XYtr1['total'].copy()
Xtr1 = XYtr1[['X.sales', 'cdate', 'fee1', 'fee2']].copy()

Xtr1_result3 = pd.concat([Xtr1,tr_result3], axis = 1)
Xtr1 = Xtr1_result3
Xtr1.drop('id',1, inplace = True)
Xtr1 = Xtr1.astype(np.float64)
Xtr1 = Xtr1.fillna(0)
Xtr1
# Out:
#       X.sales    cdate    fee1    fee2     total
# 0         1.0  18012.0   250.0   500.0  0.089986
# 1        42.0  18561.0   250.0   500.0  0.086765
# 2         3.0  18012.0   750.0  1000.0  0.101175
# 3         4.0  18012.0   750.0  1000.0  0.101175
# 4         1.0  18012.0   300.0   550.0  0.088644
# ...       ...      ...     ...     ...       ...
# 6909      3.0  18593.0   750.0  1000.0  0.085339
# 6910      2.0  18012.0   750.0  1000.0  0.225761
# 6911      2.0  18024.0     0.0   250.0  0.101175
# 6912      2.0  18790.0   200.0   450.0  0.086588
# 6913      4.0  18544.0  1000.0  1250.0  0.101175
#
# [6914 rows x 5 columns]

# %%
pred = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred.csv')

Xte = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte.csv')
te_pred = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_i.csv')
Xte1 = Xte.copy()
Xte1['cdate'] = pd.to_datetime(Xte1['cdate']).values.astype(np.float64)/8.64e+13
Xte1 = Xte1[['X.sales', 'cdate', 'fee1', 'fee2']].copy()
Xte1_pred = pd.concat([Xte1,te_pred], axis = 1)
Xte1 = Xte1_pred
Xte1.drop('id',1, inplace = True)
Xte1 = Xte1.astype(np.float64)
Xte1 = Xte1.fillna(0)
Xte1
# Out:
#       X.sales         cdate    fee1    fee2     total
# 0         2.0  18039.456434   350.0   600.0  0.089986
# 1         1.0  18012.925821   250.0   500.0  0.086765
# 2        12.0  18262.557613     0.0   250.0  0.101175
# 3         1.0  18715.717609     0.0   250.0  0.101175
# 4         1.0  18012.925943   250.0   500.0  0.088644
# ...       ...           ...     ...     ...       ...
# 6909      1.0  18520.500267  1000.0  1250.0  0.085339
# 6910      1.0  18012.925743     0.0   250.0  0.225761
# 6911      1.0  18012.925814   750.0  1000.0  0.101175
# 6912      1.0  18012.925943   250.0   500.0  0.086588
# 6913      2.0  18012.925814   750.0  1000.0  0.101175
#
# [6914 rows x 5 columns]

# %%
import warnings
warnings.filterwarnings('ignore')
# Make corpus and vocab
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

K = 50
XYtr['description'] = XYtr['description'].fillna("NAN")
Xte['description'] = Xte['description'].fillna("NAN")

corpus = list(XYtr['description'])+list(Xte['description'])
vectorizer = CountVectorizer()
bow = vectorizer.fit_transform(corpus)

# https://stackoverflow.com/questions/62777131/how-to-remove-frequent-infrequent-features-from-sklearn-countvectorizer 
# Code to remove top X% most frequent words (use this to remove stop words).

total_features = len(vectorizer.vocabulary_)
top_vect = CountVectorizer(max_features=int(total_features * 0.1))
top_bow = top_vect.fit_transform(corpus)

# Create a list of (term, frequency) tuples sorted by their frequency
sum_words = bow.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

# Keep only the terms in a list
vocabulary, _ = zip(*words_freq[:int(total_features*0.9)])
vocabulary = list(vocabulary)

bottom_vect = CountVectorizer(vocabulary=vocabulary)
corpus = bottom_vect.fit_transform(corpus)

# %%
from sklearn.decomposition import NMF
model = NMF(n_components=K, init='random', random_state=0)
model.fit(corpus)
topics = model.transform(corpus)
topics  #https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.NMF.html
N = XYtr.shape[0]

# %%
fp = open('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr_ft.csv', 'w')
fp.write('id')
for k in range(K):
    fp.write(',FT%04d' % k)

fp.write('\n')
for i in range(N):
    id = XYtr.loc[i,'id']
    fp.write('%s' % id)
    for k in range(K):
        fp.write(',%f' % topics[i, k])
    
    fp.write('\n')

fp.close()    

fp = open('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte_ft.csv', 'w')
fp.write('id')
for k in range(K):
    fp.write(',FT%04d' % k)

fp.write('\n')
for i in range(N):
    id = Xte.loc[i,'id']
    fp.write('%s' % id)
    for k in range(K):
        fp.write(',%f' % topics[i + N, k])
    
    fp.write('\n')

fp.close()

# %%
# text
Xtr_ft = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr_ft.csv')
Xtr_ft1 = Xtr_ft.copy()
Xtr_ft1.drop('id',1, inplace = True)
Xtr_ft1 = Xtr_ft1.fillna(0)

Xte_ft = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte_ft.csv')
Xte_ft1 = Xte_ft.copy()
Xte_ft1.drop('id',1, inplace = True)
Xte_ft1 = Xte_ft1.fillna(0)

# %%
Xtr5 = pd.concat([Xtr1, Xtr_ft1], axis = 1)
Xte5 = pd.concat([Xte1, Xte_ft1], axis = 1)
Xte5 = Xte5.astype(np.float64)
Xte5 = Xte5.fillna(0)


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

Xtr5 = scaler.fit_transform(Xtr5)
Xte5 = scaler.transform(Xte5)

from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import HuberRegressor, LinearRegression
model5 = SGDRegressor(loss = 'epsilon_insensitive', alpha = 0, epsilon = 0).fit(Xtr5, Ytr1)
#model5 = HuberRegressor().fit(Xtr5, Ytr1)

pred5 = pred.copy()
pred5['total'] = model5.predict(Xte5)
pred5.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred5.csv', index = False)
