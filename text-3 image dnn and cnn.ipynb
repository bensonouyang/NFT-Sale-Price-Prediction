# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import imageio
import os
from PIL import Image


import sys
sys.path 
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install -q -U keras-tuner
import keras_tuner as kt



tr = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr.csv')
tr1 =tr.copy() 
tr1['cdate'] = pd.to_datetime(tr1['cdate']).values.astype(np.float64)/8.64e+13
tr1 = tr1.fillna(0)


pred = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred.csv')

te = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte.csv')
te1 = te.copy()
te1['cdate'] = pd.to_datetime(te1['cdate']).values.astype(np.float64)/8.64e+13
te1 = te1.fillna(0)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/tanlu/Library/Python/3.9/lib/python/site-packages (21.3.1)

# %%
zz = np.zeros([tr1.shape[0],28,28])
yy = pd.qcut(tr1['total'], 10, labels = range(10))

# %%
found = list()
for ii in range(tr1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, tr1.shape[0]))
    if tr1['ext'][ii] == '.png':
        id = tr1.loc[ii,'id']
        ff = tr1.loc[ii, 'id'] + tr1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue
        
        pic = imageio.imread(path)
        pic = Image.fromarray(pic).resize((28,28))
        
        try:
            pic = np.mean(pic,axis = 2)
        except:
            pic = np.array(pic)
        
        found.append(ii)
        # print(pic.shape)
        zz[ii,:,:] = pic
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
zz = zz/255

# %%
zzte = np.zeros([tr1.shape[0],28,28])
found = list()
for ii in range(te1.shape[0]):
    if ii % 100 == 0:
        print('%d / %d' % (ii, te1.shape[0]))
    if te1['ext'][ii] == '.png':
        id = te1.loc[ii,'id']
        ff = te1.loc[ii, 'id'] + te1.loc[ii, 'ext']
        path = '/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/images/images/' + ff
        if not os.path.isfile(path):
            continue
        
        pic = imageio.imread(path)
        pic = Image.fromarray(pic).resize((28,28))
        
        try:
            pic = np.mean(pic,axis = 2)
        except:
            pic = np.array(pic)
        
        found.append(ii)
        # print(pic.shape)
        zzte[ii,:,:] = pic
# Out:
# 0 / 6914
# 100 / 6914
# 200 / 6914
# 300 / 6914
# 400 / 6914
# 500 / 6914
# 600 / 6914
# 700 / 6914
# 800 / 6914
# 900 / 6914
# 1000 / 6914
# 1100 / 6914
# 1200 / 6914
# 1300 / 6914
# 1400 / 6914
# 1500 / 6914
# 1600 / 6914
# 1700 / 6914
# 1800 / 6914
# 1900 / 6914
# 2000 / 6914
# 2100 / 6914
# 2200 / 6914
# 2300 / 6914
# 2400 / 6914
# 2500 / 6914
# 2600 / 6914
# 2700 / 6914
# 2800 / 6914
# 2900 / 6914
# 3000 / 6914
# 3100 / 6914
# 3200 / 6914
# 3300 / 6914
# 3400 / 6914
# 3500 / 6914
# 3600 / 6914
# 3700 / 6914
# 3800 / 6914
# 3900 / 6914
# 4000 / 6914
# 4100 / 6914
# 4200 / 6914
# 4300 / 6914
# 4400 / 6914
# 4500 / 6914
# 4600 / 6914
# 4700 / 6914
# 4800 / 6914
# 4900 / 6914
# 5000 / 6914
# 5100 / 6914
# 5200 / 6914
# 5300 / 6914
# 5400 / 6914
# 5500 / 6914
# 5600 / 6914
# 5700 / 6914
# 5800 / 6914
# 5900 / 6914
# 6000 / 6914
# 6100 / 6914
# 6200 / 6914
# 6300 / 6914
# 6400 / 6914
# 6500 / 6914
# 6600 / 6914
# 6700 / 6914
# 6800 / 6914
# 6900 / 6914

# %%
zzte = zzte/255
#zzte = pd.DataFrame(np.row_stack(zzte)) # https://www.codenong.com/49540922/

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (28,28)),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])
model.compile(optimizer = 'adam', loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])
model.fit(zz, yy, epochs = 50)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 0s 715us/step - loss: 2.3093 - accuracy: 0.1169
# Epoch 2/50
# 217/217 [==============================] - 0s 710us/step - loss: 2.2785 - accuracy: 0.1290
# Epoch 3/50
# 217/217 [==============================] - 0s 688us/step - loss: 2.2701 - accuracy: 0.1263
# Epoch 4/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.2594 - accuracy: 0.1435
# Epoch 5/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.2509 - accuracy: 0.1459
# Epoch 6/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.2422 - accuracy: 0.1446
# Epoch 7/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.2366 - accuracy: 0.1552
# Epoch 8/50
# 217/217 [==============================] - 0s 684us/step - loss: 2.2256 - accuracy: 0.1571
# Epoch 9/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.2169 - accuracy: 0.1598
# Epoch 10/50
# 217/217 [==============================] - 0s 710us/step - loss: 2.2110 - accuracy: 0.1663
# Epoch 11/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.2036 - accuracy: 0.1623
# Epoch 12/50
# 217/217 [==============================] - 0s 683us/step - loss: 2.1947 - accuracy: 0.1637
# Epoch 13/50
# 217/217 [==============================] - 0s 679us/step - loss: 2.1899 - accuracy: 0.1685
# Epoch 14/50
# 217/217 [==============================] - 0s 680us/step - loss: 2.1832 - accuracy: 0.1769
# Epoch 15/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.1766 - accuracy: 0.1785
# Epoch 16/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.1686 - accuracy: 0.1827
# Epoch 17/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.1627 - accuracy: 0.1846
# Epoch 18/50
# 217/217 [==============================] - 0s 683us/step - loss: 2.1674 - accuracy: 0.1838
# Epoch 19/50
# 217/217 [==============================] - 0s 680us/step - loss: 2.1523 - accuracy: 0.1911
# Epoch 20/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.1487 - accuracy: 0.1883
# Epoch 21/50
# 217/217 [==============================] - 0s 684us/step - loss: 2.1431 - accuracy: 0.1973
# Epoch 22/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.1387 - accuracy: 0.1947
# Epoch 23/50
# 217/217 [==============================] - 0s 678us/step - loss: 2.1329 - accuracy: 0.1986
# Epoch 24/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.1309 - accuracy: 0.1983
# Epoch 25/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.1254 - accuracy: 0.2026
# Epoch 26/50
# 217/217 [==============================] - 0s 683us/step - loss: 2.1182 - accuracy: 0.2016
# Epoch 27/50
# 217/217 [==============================] - 0s 698us/step - loss: 2.1216 - accuracy: 0.1999
# Epoch 28/50
# 217/217 [==============================] - 0s 747us/step - loss: 2.1134 - accuracy: 0.2015
# Epoch 29/50
# 217/217 [==============================] - 0s 720us/step - loss: 2.1101 - accuracy: 0.1970
# Epoch 30/50
# 217/217 [==============================] - 0s 686us/step - loss: 2.1056 - accuracy: 0.2089
# Epoch 31/50
# 217/217 [==============================] - 0s 688us/step - loss: 2.0999 - accuracy: 0.2106
# Epoch 32/50
# 217/217 [==============================] - 0s 684us/step - loss: 2.0961 - accuracy: 0.2129
# Epoch 33/50
# 217/217 [==============================] - 0s 685us/step - loss: 2.0900 - accuracy: 0.2099
# Epoch 34/50
# 217/217 [==============================] - 0s 701us/step - loss: 2.0886 - accuracy: 0.2181
# Epoch 35/50
# 217/217 [==============================] - 0s 690us/step - loss: 2.0871 - accuracy: 0.2107
# Epoch 36/50
# 217/217 [==============================] - 0s 688us/step - loss: 2.0849 - accuracy: 0.2107
# Epoch 37/50
# 217/217 [==============================] - 0s 682us/step - loss: 2.0913 - accuracy: 0.2068
# Epoch 38/50
# 217/217 [==============================] - 0s 683us/step - loss: 2.0789 - accuracy: 0.2158
# Epoch 39/50
# 217/217 [==============================] - 0s 680us/step - loss: 2.0762 - accuracy: 0.2204
# Epoch 40/50
# 217/217 [==============================] - 0s 680us/step - loss: 2.0719 - accuracy: 0.2142
# Epoch 41/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.0674 - accuracy: 0.2146
# Epoch 42/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.0652 - accuracy: 0.2233
# Epoch 43/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.0627 - accuracy: 0.2164
# Epoch 44/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.0609 - accuracy: 0.2236
# Epoch 45/50
# 217/217 [==============================] - 0s 678us/step - loss: 2.0567 - accuracy: 0.2266
# Epoch 46/50
# 217/217 [==============================] - 0s 681us/step - loss: 2.0562 - accuracy: 0.2210
# Epoch 47/50
# 217/217 [==============================] - 0s 702us/step - loss: 2.0521 - accuracy: 0.2229
# Epoch 48/50
# 217/217 [==============================] - 0s 742us/step - loss: 2.0539 - accuracy: 0.2258
# Epoch 49/50
# 217/217 [==============================] - 0s 700us/step - loss: 2.0619 - accuracy: 0.2235
# Epoch 50/50
# 217/217 [==============================] - 0s 684us/step - loss: 2.0461 - accuracy: 0.2235

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
pred_i = pred.copy()
pred_i['total'] = probability_model.predict(zzte)
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_image.csv', index = False)
#probability_model.save_weights('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/tensor_text_model.csv')

# %%
#prof code
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])
predictions = probability_model.predict(zzte)
result = np.argmax(predictions,axis = 1)
qq = np.quantile(tr['total'],q = np.array(range(1,11))/11)
result2 = qq[result]
result3 = result2
pred_i = pred.copy()
pred_i['total'] = result3
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_image.csv', index = False)

# %%
# cnn

def create_cnn(width = 28, height = 28, regress = False):
    inputShape = (height,width)
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(filters = 32,kernel_size = 3 ,activation = 'relu',input_shape = (28,28,1),padding = "same"))
    model.add(tf.keras.layers.MaxPooling2D(pool_size = 2))
    model.add(tf.keras.layers.Conv2D(filters = 64,kernel_size = 3 ,activation = 'relu',padding = "same"))
    model.add(tf.keras.layers.MaxPooling2D(pool_size = 2))
    model.add(tf.keras.layers.Conv2D(filters = 128,kernel_size = 3 ,activation = 'relu',padding = "same"))

    model.add(tf.keras.layers.Flatten())
    #model.add(tf.keras.layers.Dense(128, activation = 'relu'))
    #model.add(tf.keras.layers.Dropout(0.5))
    #model.add(tf.keras.layers.Dense(64, activation = 'relu'))
    #model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(10, activation = 'softmax'))
    #if regress:
    #    model.add(tf.keras.layers.Dense(1, activation="linear"))
    return model

# %%
cnn = create_cnn(28,28,regress = False)
# opt = tf.keras.optimizers.Adam(learning_rate=1e-1, decay=1e-1 / 100)
# model.compile(loss="mean_absolute_error", optimizer=opt)
cnn.compile(loss='sparse_categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
cnn.fit(x= zz, y=yy,epochs= 50)
probability_model = tf.keras.Sequential([cnn, tf.keras.layers.Softmax()])
pred_i = pred.copy()
pred_i['total'] = probability_model.predict(zzte)
pred_i.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_image.csv', index = False)
# Out:
# Epoch 1/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.2932 - accuracy: 0.1177
# Epoch 2/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.2670 - accuracy: 0.1446
# Epoch 3/50
# 217/217 [==============================] - 3s 13ms/step - loss: 2.2305 - accuracy: 0.1600
# Epoch 4/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.1891 - accuracy: 0.1756
# Epoch 5/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.1404 - accuracy: 0.1929
# Epoch 6/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.0897 - accuracy: 0.2159
# Epoch 7/50
# 217/217 [==============================] - 3s 14ms/step - loss: 2.0355 - accuracy: 0.2376
# Epoch 8/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.9792 - accuracy: 0.2573
# Epoch 9/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.9336 - accuracy: 0.2767
# Epoch 10/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.8682 - accuracy: 0.2965
# Epoch 11/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.8245 - accuracy: 0.3150
# Epoch 12/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.7741 - accuracy: 0.3354
# Epoch 13/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.7422 - accuracy: 0.3487
# Epoch 14/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.7084 - accuracy: 0.3640
# Epoch 15/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6656 - accuracy: 0.3707
# Epoch 16/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6459 - accuracy: 0.3814
# Epoch 17/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.6317 - accuracy: 0.3881
# Epoch 18/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5985 - accuracy: 0.3988
# Epoch 19/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5811 - accuracy: 0.4014
# Epoch 20/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5679 - accuracy: 0.4069
# Epoch 21/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5527 - accuracy: 0.4082
# Epoch 22/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5434 - accuracy: 0.4142
# Epoch 23/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5293 - accuracy: 0.4151
# Epoch 24/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5464 - accuracy: 0.4118
# Epoch 25/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.5156 - accuracy: 0.4228
# Epoch 26/50
# 217/217 [==============================] - 3s 15ms/step - loss: 1.5078 - accuracy: 0.4254
# Epoch 27/50
# 217/217 [==============================] - 3s 15ms/step - loss: 1.5107 - accuracy: 0.4239
# Epoch 28/50
# 217/217 [==============================] - 3s 15ms/step - loss: 1.5076 - accuracy: 0.4277
# Epoch 29/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4939 - accuracy: 0.4257
# Epoch 30/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4894 - accuracy: 0.4254
# Epoch 31/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4801 - accuracy: 0.4312
# Epoch 32/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4802 - accuracy: 0.4288
# Epoch 33/50
# 217/217 [==============================] - 3s 15ms/step - loss: 1.4834 - accuracy: 0.4277
# Epoch 34/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4705 - accuracy: 0.4351
# Epoch 35/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4680 - accuracy: 0.4367
# Epoch 36/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4654 - accuracy: 0.4385
# Epoch 37/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4583 - accuracy: 0.4411
# Epoch 38/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4566 - accuracy: 0.4427
# Epoch 39/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4579 - accuracy: 0.4403
# Epoch 40/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4521 - accuracy: 0.4349
# Epoch 41/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4471 - accuracy: 0.4393
# Epoch 42/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4490 - accuracy: 0.4416
# Epoch 43/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4564 - accuracy: 0.4429
# Epoch 44/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4501 - accuracy: 0.4437
# Epoch 45/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4434 - accuracy: 0.4445
# Epoch 46/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4379 - accuracy: 0.4453
# Epoch 47/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4373 - accuracy: 0.4450
# Epoch 48/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4285 - accuracy: 0.4510
# Epoch 49/50
# 217/217 [==============================] - 3s 14ms/step - loss: 1.4264 - accuracy: 0.4498
# Epoch 50/50
# 217/217 [==============================] - 3s 13ms/step - loss: 1.4342 - accuracy: 0.4478

# %%
def create_mlp(dim, regress = False):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(8, input_dim = dim, activation = "relu"))
    model.add(tf.keras.layers.Dense(8, activation = "relu"))
    
    if regress:
        model.add(tf.keras.layers.Dense(1,activation = "linear"))
    return model

# %%
XYtr = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/XYtr.csv')


XYtr1 = XYtr.copy() # from stackoverflow
XYtr1['cdate'] = pd.to_datetime(XYtr1['cdate']).values.astype(np.float64)/8.64e+13

Y = XYtr1['total'].copy()
Xtr1 = XYtr1[['X.sales', 'cdate', 'fee1', 'fee2']].copy()

Xtr1 = Xtr1.astype(np.float64)

Xtr1 = Xtr1.fillna(0)

pred = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred.csv')

Xte = pd.read_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/Xte.csv')

Xte1 = Xte.copy()
Xte1['cdate'] = pd.to_datetime(Xte1['cdate']).values.astype(np.float64)/8.64e+13
Xte1 = Xte1[['X.sales', 'cdate', 'fee1', 'fee2']].copy()
Xte1 = Xte1.astype(np.float64)
Xte1 = Xte1.fillna(0)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

Xtr6 = scaler.fit_transform(Xtr1)

Xte6 = scaler.transform(Xte1)

# %%
mlp = create_mlp(Xtr6.shape[1], regress = False)
combinedInput = tf.keras.layers.concatenate([mlp.output,probability_model.output])
# combinedInput = tf.keras.layers.concatenate([mlp.output,cnn.output])

x = tf.keras.layers.Dense(4, activation="relu")(combinedInput)
x = tf.keras.layers.Dense(1, activation="linear")(x)
# our final model will accept categorical/numerical data on the MLP
# input and images on the CNN input, outputting a single value (the
# predicted price of the house)
model = tf.keras.Model(inputs=[mlp.input, probability_model.input], outputs=x)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-4, epsilon = 0.1)
model.compile(loss="mean_absolute_error", optimizer=opt,metrics = ['accuracy'])
print("[INFO] training model...")
model.fit(x=[Xtr6, zz], y=Y,epochs=50)
# Out:
# [INFO] training model...
# Epoch 1/50
# 217/217 [==============================] - 4s 15ms/step - loss: 9.4602 - accuracy: 0.0205
# Epoch 2/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4588 - accuracy: 0.0205
# Epoch 3/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4576 - accuracy: 0.0205
# Epoch 4/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4566 - accuracy: 0.0205
# Epoch 5/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4559 - accuracy: 0.0207
# Epoch 6/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4554 - accuracy: 0.0207
# Epoch 7/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4550 - accuracy: 0.0207
# Epoch 8/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4546 - accuracy: 0.0208
# Epoch 9/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4543 - accuracy: 0.0208
# Epoch 10/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4540 - accuracy: 0.0208
# Epoch 11/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4537 - accuracy: 0.0208
# Epoch 12/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4534 - accuracy: 0.0208
# Epoch 13/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4531 - accuracy: 0.0208
# Epoch 14/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4529 - accuracy: 0.0208
# Epoch 15/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4527 - accuracy: 0.0208
# Epoch 16/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4524 - accuracy: 0.0208
# Epoch 17/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4522 - accuracy: 0.0208
# Epoch 18/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4521 - accuracy: 0.0208
# Epoch 19/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4519 - accuracy: 0.0207
# Epoch 20/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4517 - accuracy: 0.0207
# Epoch 21/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4515 - accuracy: 0.0207
# Epoch 22/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4514 - accuracy: 0.0207
# Epoch 23/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4512 - accuracy: 0.0207
# Epoch 24/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4510 - accuracy: 0.0207
# Epoch 25/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4508 - accuracy: 0.0207
# Epoch 26/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4507 - accuracy: 0.0207
# Epoch 27/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4506 - accuracy: 0.0207
# Epoch 28/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4504 - accuracy: 0.0205
# Epoch 29/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4502 - accuracy: 0.0207
# Epoch 30/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4500 - accuracy: 0.0207
# Epoch 31/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4499 - accuracy: 0.0207
# Epoch 32/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4497 - accuracy: 0.0207
# Epoch 33/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4495 - accuracy: 0.0207
# Epoch 34/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4494 - accuracy: 0.0205
# Epoch 35/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4492 - accuracy: 0.0207
# Epoch 36/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4490 - accuracy: 0.0207
# Epoch 37/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4489 - accuracy: 0.0207
# Epoch 38/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4487 - accuracy: 0.0207
# Epoch 39/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4486 - accuracy: 0.0207
# Epoch 40/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4484 - accuracy: 0.0208
# Epoch 41/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4483 - accuracy: 0.0207
# Epoch 42/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4482 - accuracy: 0.0205
# Epoch 43/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4479 - accuracy: 0.0205
# Epoch 44/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4478 - accuracy: 0.0207
# Epoch 45/50
# 217/217 [==============================] - 3s 14ms/step - loss: 9.4477 - accuracy: 0.0207
# Epoch 46/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4476 - accuracy: 0.0207
# Epoch 47/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4474 - accuracy: 0.0205
# Epoch 48/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4473 - accuracy: 0.0205
# Epoch 49/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4471 - accuracy: 0.0207
# Epoch 50/50
# 217/217 [==============================] - 3s 15ms/step - loss: 9.4470 - accuracy: 0.0205

# %%
predrf = pred.copy()
predrf['total'] = model.predict([Xte6,zzte])
predrf.to_csv('/Users/tanlu/Desktop/~/2021 Fall/Stat 440/project2/stat440-21-project2/pred_image.csv', index = False)
predrf
# Out:
#                                     id     total
# 0     7e79f1a9cb10504dd2fc569d84f2a346  0.028923
# 1     4a2f52a31466509462042dacd3d66de7  0.015790
# 2     f22f6ec19360a7bcc7e0f6c76912c88b  0.097219
# 3     6382e9933644b1751511264ec8194ef5  0.064512
# 4     638c2f2961777b10009d7fdebae561bc  0.016660
# ...                                ...       ...
# 6909  62eb6ce056e943070967d8835a204551  0.484879
# 6910  6a5a9ef25ea4889cef2b14a272ba958c  0.023321
# 6911  6c8edfdb7aec834d73e4b8d36ec0736d  0.198219
# 6912  c4618bb91765903dad4451933ee396ea  0.015379
# 6913  3b665129694904b2024dc7cd8230babe  0.198203
#
# [6914 rows x 2 columns]
